# %%
# !python mainV6x4.py --epoch 200 --lr 0.0002 --batch-size 1 --name 'PTSR31AUG+bicubic+s5+newdiffloss2+nonorm+x4' --gpuid 1
# Out:
# Dataloader
# 800 ../dataset/div2klrx4
# tot_batch 800
# ...
# 100%|████████████████████████████████| 160001/160001 [11:13:43<00:00,  3.96it/s]
# 100 ../dataset/DIV2K_valid_HR
# Traceback (most recent call last):
#   File "mainV6x4.py", line 258, in <module>
#     train(netG, netD, optimizer_g,optimizer_d, data_loader,tot_batch, device)
#   File "mainV6x4.py", line 194, in train
#     psnr,psnr2,ssim,ssim2=test(generator)
# ValueError: too many values to unpack (expected 4)

# %%
# !pip install numpy

# %%
# %matplotlib inline 
# !python test.py --batch-size 1  --weight './PTSR22AUG+x4+ar2j' --gpuid 0
# Out:
# Traceback (most recent call last):
#   File "test.py", line 169, in <module>
#     netG.load_state_dict(copy.deepcopy(torch.load(str(args.weight)+"/weights/Generator.pth")))
#   File "/home/oem/anaconda3/envs/trans/lib/python3.6/site-packages/torch/nn/modules/module.py", line 1483, in load_state_dict
#     self.__class__.__name__, "\n\t".join(error_msgs)))
# RuntimeError: Error(s) in loading state_dict for DataParallel:
# ...

# %%
# %matplotlib inline 
# !python testsa.py --batch-size 1  --weight './PTSR22AUG+ar2'
# Out:
# 5 ../dataset/Set5
#   0%|                                                     | 0/5 [00:00<?, ?it/s]/home/oem/anaconda3/envs/trans/lib/python3.6/site-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# 100%|█████████████████████████████████████████████| 5/5 [00:01<00:00,  2.78it/s]
# 14 ../dataset/Set14
# 100%|███████████████████████████████████████████| 14/14 [00:03<00:00,  4.26it/s]
# 100 ../dataset/BSD100
# 100%|█████████████████████████████████████████| 100/100 [00:23<00:00,  4.34it/s]
# 100 ../dataset/urban100
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  
# Fixing random state for reproducibility


x=np.random.random((100, 100))
print(x.shape)
plt.subplot(121)
plt.imshow(x)
plt.subplot(122)
plt.imshow(np.random.random((100, 100)))

plt.subplots_adjust(bottom=0.0, right=.9, top=1)
cax = plt.axes([0.9, 0.1, 0.08, 0.8])
plt.colorbar(cax=cax)

plt.show()
